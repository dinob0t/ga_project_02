# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.simplefilter("ignore", DeprecationWarning)

# %%
# If running for the first time set 'fresh'=1 for a fresh run
# otherwise pre-load the data from file
# takes a few mins to run the first time
fresh = 1
if fresh == 1:
    df = pd.read_csv('baseball.csv')
else:
    df = pd.read_pickle('df_baseball.pkl')

# %%
# All the features we have to work with
#1 "playerID" - Unique number 
#2 "lahmanID" - Unique code
#3 "managerID" - Manager ID
#4 "hofID" - Hall of fame ID
#5 "birthYear"
#6 "birthMonth"
#7 "birthDay"
#8 "birthCountry"
#9 "birthState"
#10 "birthCity"
#11 "deathYear"
#12 "deathMonth"
#13 "deathDay"
#14 "deathCountry"
#15 "deathState"
#16 "deathCity"
#17 "nameFirst"
#18 "nameLast"
#19 "nameNote" - Indicates changed name or played under diff name
#20 "nameGiven"
#21 "nameNick" - Nick name
#22 "weight" - weight in poinds
#23 "height" - height in inches
#24 "bats" - left, right, or both
#25 "throws" - left or right
#26 "debut" - date of first major league appearance
#27 "finalGame" - date of last ....
#28 "college" - College attended
#29 "lahman40ID" - lahman id 4.0
#30 "lahman45ID" - lahman id 4.5
#31 "retroID" - retrosheet id
#32 "holtzID" - Hotlz almanac ID
#33 "bbrefID" - Baseball reference website ID
#34 "deathDate"
#35 "birthDate"
#36 "yearID" - year for data
#37 "teamID" - team
#38 "lgID" - league
#39 "stint" - order of appearances within a season
#40 "G" - games
#41 "G_batting" - game as batter
#42 "AB" - at bats
#43 "R" - runs
#44 "H" - hits
#45 "X2B" - doubles 
#46 "X3B" - triples
#47 "HR" - homerunes
#48 "RBI" - runs batted in
#49 "SB" - stolen bases
#50 "CS" - caught stealing
#51 "BB" - base on balls
#52 "SO" - strikeouts
#53 "IBB" - intentional walks
#54 "HBP" - hit by pitch
#55 "SH" - sacrifice hits
#56 "SF" - sacrifice flies
#57 "GIDP" - grounded into double plays
#58 "G_old" - old verison of games
#59 "salary" - salary that year

# %%
#1 playerID       Player ID code
#2 yearID         Year
#3 stint          player's stint (order of appearances within a season)
#4 teamID         Team
#5 lgID           League
#6 W              Wins
#7 L              Losses
#8 G              Games
#9 GS             Games Started
#10 CG             Complete Games 
#11 SHO            Shutouts
#12 SV             Saves
#13 IPOuts         Outs Pitched (innings pitched x 3)
#14 H              Hits
#15 ER             Earned Runs
#16 HR             Homeruns
#17 BB             Walks
#18 SO             Strikeouts
#19 BAOpp          Opponent's Batting Average
#20 ERA            Earned Run Average
#21 IBB            Intentional Walks
#22 WP             Wild Pitches
#23 HBP            Batters Hit By Pitch
#24 BK             Balks
#25 BFP            Batters faced by Pitcher
#26 GF             Games Finished
#27 R              Runs Allowed
#28 SH             Sacrifices by opposing batters
#29 SF             Sacrifice flies by opposing batters
#30 GIDP           Grounded into double plays by opposing batter

# %%
# Fielding stats
# playerID       Player ID code
# yearID         Year
# stint          player's stint (order of appearances within a season)
# teamID         Team
# lgID           League
# Pos            Position
# G              Games 
# GS             Games Started
# InnOuts        Time played in the field expressed as outs 
# PO             Putouts
# A              Assists
# E              Errors
# DP             Double Plays
# PB             Passed Balls (by catchers)
# WP             Wild Pitches (by catchers)
# SB             Opponent Stolen Bases (by catchers)
# CS             Opponents Caught Stealing (by catchers)
# ZR             Zone Rating

# %%
# Combines features from the pitching data into our existing data.
# Note: Patrick had a nice way of doing this in class today with 'merge' (faster!)
# He also dropped a bunch of pitching data that appears in the existing data but 
# when I wrote this I didn't know that those features meant the same thing for 
# batters vs. pitchers

def add_pitching(df_in):
    df_pitching = pd.read_csv('Pitching.csv')
    df_pitching = df_pitching[df_pitching.yearID >= min(df_in.yearID)]
    count = 0
    # Add new blank columns for all added pitching data
    zero_list = np.zeros([df_in.shape[0]]) 
    pitching_features = ['W', 'L', 'G', 'GS', 'CG', 'SHO', 'SV', 'IPouts', 'H', 'ER', 'HR', 'BB', 'SO', 'ERA', 'WP', 'HBP', 'BK', 'BFP', 'GF', 'R']
    # All pitching features append 'p' out the front
    for feature in pitching_features:
        new_str = 'p'+feature
        df_in[new_str] = zero_list    
    for row in df_in.iterrows():     
        cur_playerID = row[1].playerID
        cur_year = row[1].yearID
        row_lookup = (df_pitching.playerID == cur_playerID) & (df_pitching.yearID == cur_year)
        for feature in pitching_features:
            cur_val = df_pitching.loc[row_lookup,feature].values
            if len(cur_val)>0:
                cur_val = cur_val[0]
            else:
                # Set missing data here to zero. Is this reasonable?
                cur_val = 0.0
            new_str = 'p'+feature
            df_in.ix[count,new_str] = cur_val
        count +=1
    return df_in

# %%
# Combines features from the fielding data into our existing data.

def add_fielding(df_in):
    df_fielding = pd.read_csv('Fielding.csv')
    df_fielding = df_fielding[df_fielding.yearID >= min(df_in.yearID)]
    count = 0
    # Add new blank columns for all added fielding data
    zero_list = np.zeros([df_in.shape[0]]) 
    fielding_features = ['PO', 'A', 'E', 'InnOuts']
    # All fielding features append 'p' out the front
    for feature in fielding_features:
        new_str = 'f'+feature
        df_in[new_str] = zero_list    
    for row in df_in.iterrows():     
        cur_playerID = row[1].playerID
        cur_year = row[1].yearID
        row_lookup = (df_fielding.playerID == cur_playerID) & (df_fielding.yearID == cur_year)
        for feature in fielding_features:
            cur_val = df_fielding.loc[row_lookup,feature].values
            if len(cur_val)>0:
                cur_val = cur_val[0]
            else:
                # Set missing data here to zero. Is this reasonable?
                cur_val = 0.0
            new_str = 'f'+feature
            df_in.ix[count,new_str] = cur_val
        count +=1
    return df_in

# %%
if fresh == 1:
    df = add_pitching(df)
    df = add_fielding(df)

# %%
if fresh ==1:
    # Replace HOFID with binary 0 no, 1 yes
    df['hofID'].fillna(0.0,inplace=True)
    df.loc[df['hofID'] != 0.0,'hofID'] = 1.0
    # Replace nickname with binary
    df['nameNick'].fillna(0.0,inplace=True)
    df.loc[df['nameNick'] != 0.0,'nameNick'] = 1.0
    # Replace throws and bats L = 0, R = 1
    df.loc[df['bats'] =='L','bats'] = 0.0
    df.loc[df['bats'] =='R','bats'] = 1.0
    df.loc[df['bats'] =='B','bats'] = 2.0
    df.loc[df['throws'] =='L','throws'] = 0.0
    df.loc[df['throws'] =='R','throws'] = 1.0
    # Delete weird data
    df = df[df.salary > 1]
    df = df[df.yearID > 1]
    df = df[df.weight > 2]
    df = df[df.height > 2]
    df = df.drop(['birthDate','bbrefID','college','nameGiven','birthCity','birthState','birthCountry','debut','finalGame','managerID','deathYear','deathMonth','deathCountry','deathState','deathDate','deathDay', 'lahman40ID', 'lahman45ID', 'retroID', 'holtzID','deathCity','nameFirst','nameLast','nameNote','G_old','lahmanID'],axis=1)
    # Set remaning NaN stats to zero
    # Based on assumption that the missing data is missing batting data from pitchers
    # Can this be improved? Should we just delete it
    for feature in df.columns:
        null_mask = pd.isnull(df[feature])
        # If they are missing batting data, but pitching data exists...
        if feature not in ['fPO', 'fA', 'fE', 'fInnOuts']:
            df.loc[(null_mask)& df.pERA!=0,feature] = 0.0
        else:
        # If they are missing fielding data, but batting or pitching data exists...
            df.loc[(null_mask)& df.pERA!=0,feature] = 0.0
            df.loc[(null_mask)& df.AB!=0,feature] = 0.0
    # Remove few remaining NaNs    
    df.dropna(how='any',inplace=True)

    # Add in age
    df['age'] = df['yearID']-df['birthYear']
    # Add in batting ratio -> 0 pitchers, 1 batters
    df['Batting_ratio']=df.G_batting/df.G
    # Sort for cumulative stats below
    df = df.sort(columns=['playerID','yearID'])
    df.index = range(0,len(df))

# %%
# df.to_pickle('df_baseball.pkl')
# df[['H','R','X2B','X3B','HR']]

# %%
def add_pitching_stats(df_in):
    # Walks and hits per innings
    df_in['pWHIP'] = 3.0*(df_in['pH'] + df_in['pBB'])/df_in['pIPouts']
    null_mask = pd.isnull(df_in['pWHIP'])
    df_in.loc[null_mask,'pWHIP'] = 0.0
    # Winning percentage
    df_in['pWP'] = df_in['pW']/(df_in['pW'] + df_in['pL'])
    null_mask = pd.isnull(df_in['pWP'])
    df_in.loc[null_mask,'pWP'] = 0.0
    return df_in
#     df_in.replace([np.inf, -np.inf],0.0)

# %%
def add_offensive_stats(df_in):

    # Total base percentage
    df_in['TBP'] = (df_in['H']+df_in['BB']+df_in['HBP'])/(df_in['AB']+df_in['BB'] + df_in['HBP'])
    null_mask = pd.isnull(df_in['TBP'])
    df_in.loc[null_mask,'TBP'] = 0.0    
    
    # Plate appearane
    df_in['PA'] = (df_in['AB']+df_in['BB']+df_in['HBP'] +df_in['SH']+df_in['SF'])
    null_mask = pd.isnull(df_in['PA'])
    df_in.loc[null_mask,'PA'] = 0.0

    # Total bases
    df_in['TB'] = (df_in['H']+2.0*df_in['X2B']+3.0*df_in['X3B'] +4.0*df_in['HR'])
    null_mask = pd.isnull(df_in['TB'])
    df_in.loc[null_mask,'TB'] = 0.0

    # Batting average
    df_in['AVG'] = (df_in['H'])/(df_in['AB'])
    null_mask = pd.isnull(df_in['AVG'])
    df_in.loc[null_mask,'AVG'] = 0.0
    
    # Base on balls percentage
    df_in['BOB'] = (df_in['BB'])/(df_in['PA'])
    null_mask = pd.isnull(df_in['AVG'])
    df_in.loc[null_mask,'AVG'] = 0.0    
    
    # Home run ratio
    df_in['HRR'] = (df_in['HR'])/(df_in['AB'])
    null_mask = pd.isnull(df_in['HRR'])
    df_in.loc[null_mask,'HRR'] = 0.0     
    
    # On Base percentage
    df_in['OBP'] = (df_in['H']+df_in['BB']+df_in['HBP'])/(df_in['AB'] +df_in['BB'] + df_in['HBP']+ df_in['SF'])
    null_mask = pd.isnull(df_in['OBP'])
    df_in.loc[null_mask,'OBP'] = 0.0  
    
    # Slugging average
    df_in['SA'] = (df_in['TB'])/(df_in['AB'])
    null_mask = pd.isnull(df_in['SA'])
    df_in.loc[null_mask,'SA'] = 0.0
    
    
    # On Base Plus Slugging
    df_in['OBPS'] = df_in['SA'] + df_in['OBP']
    null_mask = pd.isnull(df_in['OBPS'])
    df_in.loc[null_mask,'OBPS'] = 0.0  
    
    # Strike out ratio
    df_in['SOR'] = (df_in['SO'])/(df_in['AB'])
    null_mask = pd.isnull(df_in['SOR'])
    df_in.loc[null_mask,'SOR'] = 0.0
    
    # Isolated power
    df_in['ISO'] = (df_in['TB'] - df_in['H'])/(df_in['AB'])
    null_mask = pd.isnull(df_in['ISO'])
    df_in.loc[null_mask,'ISO'] = 0.0
    
    return df_in

# %%
def add_defensive_stats(df_in):
    # Fielding Average
    df_in['fFA'] = (df_in['fPO'] +df_in['fA'])/(df_in['fPO'] +df_in['fA'] + df_in['fE'])
    null_mask = pd.isnull(df_in['fFA'])
    df_in.loc[null_mask,'fFA'] = 0.0
    
    # Range Factor
    df_in['fRF'] = 9.0*(df_in['fPO'] +df_in['fA'])/df_in['fInnOuts']
    null_mask = pd.isnull(df_in['fRF'])
    df_in.loc[null_mask,'fRF'] = 0.0
    return df_in

# %%
if fresh == 1:
    df = add_pitching_stats(df)
    df = add_offensive_stats(df)
    df = add_defensive_stats(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-158-10caf3b761dd> in <module>()
#       1 if fresh == 1:
#       2     df = add_pitching_stats(df)
# ----> 3     df = add_offensive_stats(df)
#       4     df = add_defensive_stats(df)
#
# <ipython-input-157-f0bcfca762d1> in add_offensive_stats(df_in)
#      32
#      33     # On Base percentage
# ---> 34     df_in['OBP'] = (df_in['H']+df_in['BB']+df_in['HBP'])/(df_in['AB'] +df_in['W'] + df_in['HBP']+ df_in['SF'])
#      35     null_mask = pd.isnull(df_in['OBP'])
#      36     df_in.loc[null_mask,'OBP'] = 0.0
#
# /Users/dino/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1656             return self._getitem_multilevel(key)
#    1657         else:
# -> 1658             return self._getitem_column(key)
#    1659
#    1660     def _getitem_column(self, key):
#
# /Users/dino/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1663         # get column
#    1664         if self.columns.is_unique:
# -> 1665             return self._get_item_cache(key)
#    1666
#    1667         # duplicate columns & possible reduce dimensionaility
#
# /Users/dino/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1003         res = cache.get(item)
#    1004         if res is None:
# -> 1005             values = self._data.get(item)
#    1006             res = self._box_item_values(item, values)
#    1007             cache[item] = res
#
# /Users/dino/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item)
#    2871                 return self.get_for_nan_indexer(indexer)
#    2872
# -> 2873             _, block = self._find_block(item)
#    2874             return block.get(item)
#    2875         else:
#
# /Users/dino/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _find_block(self, item)
#    3183
#    3184     def _find_block(self, item):
# -> 3185         self._check_have(item)
#    3186         for i, block in enumerate(self.blocks):
#    3187             if item in block:
#
# /Users/dino/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _check_have(self, item)
#    3190     def _check_have(self, item):
#    3191         if item not in self.items:
# -> 3192             raise KeyError('no item named %s' % com.pprint_thing(item))
#    3193
#    3194     def reindex_axis(self, new_axis, indexer=None, method=None, axis=0,
#
# KeyError: u'no item named W'

# %%
# Add in years with they have been with their current club
# Must be sorted for this to work
# This turns out to be a strong predicter!
def add_ywc(df_in):
    count = 0
    df_in['ywc'] = np.zeros([df_in.shape[0]])
    for row in df_in.iterrows():
        if count == 0:
            df_in.ix[count,'ywc'] = 1
            prev_playerID = row[1].playerID
            prev_team = row[1].teamID
            prev_year = row[1].yearID
        else:            
            cur_playerID = row[1].playerID
            cur_team = row[1].teamID
            cur_year = row[1].yearID
            if cur_playerID == prev_playerID and cur_team == prev_team and cur_year == prev_year+1:
                df_in.ix[count,'ywc'] = df_in.ix[count-1,'ywc'] + 1
                prev_year = cur_year
            else:
                df_in.ix[count,'ywc'] = 1
                prev_playerID = cur_playerID
                prev_team = cur_team
                prev_year = cur_year
        
        count += 1
    return df_in

# %%
# Add in years with club
if fresh == 1:
    df = add_ywc(df)

# %%
# Try cumulative stats over their careers
# This turns out to be generally weak as features
def add_cum_stats(df_in):
    
    zero_list = np.zeros([df_in.shape[0]]) 
    features= ['G', 'G_batting', 'AB', 'R', 'H', 'X2B', 'X3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP', 'salary', 'pW', 'pL', 'pG', 'pGS', 'pCG', 'pSHO', 'pSV', 'pIPouts', 'pH', 'pER', 'pHR', 'pBB', 'pSO', 'pERA', 'pWP', 'pHBP', 'pBK', 'pBFP', 'pGF', 'pR']
    for feature in features:
        new_str = feature + '_cum'
        df_in[new_str] = zero_list

    count = 0
    cur_playerID = ''   
    for row in df_in.iterrows(): 
        if row[1].playerID == cur_playerID:
            
            for feature in features:
                new_str = feature + '_cum'
                df_in.ix[count,new_str] = df_in.ix[count-1,new_str] + df_in.ix[count,feature] 
        else:
            for feature in features:
                new_str = feature + '_cum'
                df_in.ix[count,new_str] = df_in.ix[count,feature] 
            cur_playerID = row[1].playerID
        count += 1
        if count > 30:
            break  
    return df_in

# %%
# Add in cumulative stats
if fresh == 1:
    df = add_cum_stats(df)

# %%
# Ranking of the teams based on some analysis Lema did
# Should this be replace with rankings 1-30ish?
# The NYA appear to be way out in front of their neighbours
# Should we just collapse this to a binary is_NYA variable?
def replace_teams(df_in):
    df_in['teamID_ranking'] = df_in['teamID']
    df_in['is_NYA'] = df_in['teamID']
    
    pay_dict = {'TBA':0.563012316,
    'FLO':0.590202151,
    'WAS':0.628968556,
    'MON':0.640852974,
    'PIT':0.644590508,
    'MIL':0.765931924,
    'SDN':0.810817752,
    'ML4':0.821061606,
    'OAK':0.830736393,
    'MIN':0.851800958,
    'KCA':0.855405149,
    'CLE':0.864584478,
    'CIN':0.895130092,
    'COL':0.900445365,
    'ARI':0.949687104,
    'HOU':0.985782018,
    'ANA':0.992457703,
    'SEA':0.993221428,
    'TEX':0.996291621,
    'CAL':1.020107846,
    'CHA':1.029691571,
    'BAL':1.030425975,
    'PHI':1.031248116,
    'DET':1.037312589,
    'TOR':1.037545033,
    'SLN':1.066267649,
    'SFN':1.076192579,
    'CHN':1.173932516,
    'ATL':1.213932799,
    'LAN':1.250521203,
    'MIA':1.258127264,
    'NYN':1.307755738,
    'LAA':1.317793839,
    'BOS':1.388804819,
    'NYA':1.814579156}
    rank_dict = {'TBA':1,
    'FLO':2,
    'WAS':3,
    'MON':4,
    'PIT':5,
    'MIL':6,
    'SDN':7,
    'ML4':8,
    'OAK':9,
    'MIN':10,
    'KCA':11,
    'CLE':12,
    'CIN':13,
    'COL':14,
    'ARI':15,
    'HOU':16,
    'ANA':17,
    'SEA':18,
    'TEX':19,
    'CAL':20,
    'CHA':21,
    'BAL':22,
    'PHI':23,
    'DET':24,
    'TOR':25,
    'SLN':26,
    'SFN':27,
    'CHN':28,
    'ATL':29,
    'LAN':30,
    'MIA':31,
    'NYN':32,
    'LAA':33,
    'BOS':34,
    'NYA':35}   
    for team in pay_dict.keys():
        df_in.teamID.replace(to_replace=team,value=pay_dict[team],inplace=True)
        df_in.teamID_ranking.replace(to_replace=team,value=rank_dict[team],inplace=True)
        if team != 'NYA'
            df_in.is_NYA.replace(to_replace=team,value=0.0,inplace=True)
        else:
            df_in.is_NYA.replace(to_replace=team,value=1.0,inplace=True)
    return df_in

# %%
# Replace teams with rankings
if fresh == 1:
    df = replace_teams(df)

# %%
# Log of the stats
def log_stats(df_in):
    df_in['log_ywc'] = np.log(df_in.ywc)
    df_in['log_salary'] = np.log(df_in.salary)
    # Appy to all batting / pitching stats
    features= ['G', 'G_batting', 'AB', 'R', 'H', 'X2B', 'X3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP', 'salary', 'pW', 'pL', 'pG', 'pGS', 'pCG', 'pSHO', 'pSV', 'pIPouts', 'pH', 'pER', 'pHR', 'pBB', 'pSO', 'pERA', 'pWP', 'pHBP', 'pBK', 'pBFP', 'pGF', 'pR']
    for feature in features:
        new_str = 'log_' + feature
        df_in[new_str] = df_in[feature]
        select_gt_zero = df_in[feature]>0
        df_in.loc[select_gt_zero,new_str] = np.log(df_in.loc[select_gt_zero,feature])
    return df_in

# %%
# Log of stats
if fresh == 1:
    df = log_stats(df)

# %%
if fresh == 1
    df.to_pickle('df_baseball.pkl')

# Something we were looking at today in class
# Might indicate which features are useful
corr_series = df.corr().ix[:,'log_salary']
for indx,row in corr_series.iteritems():
    print indx, row
# Out:
# lahmanID 0.0442792050395
# hofID 0.199579562752
# birthYear 0.148848737939
# birthMonth 0.0226178840941
# birthDay 0.0195638835482
# nameNick 0.211227772659
# weight 0.159694302376
# height 0.0497638951791
# bats -0.00488904859604
# throws 0.007477570509
# yearID 0.435712317597
# teamID 0.134922096233
# stint -0.069920832456
# G 0.248507634785
# G_batting 0.190626486036
# AB 0.267544005327
# R 0.286618687082
# H 0.274848318311
# X2B 0.279017666191
# X3B 0.0968908028471
# HR 0.306857528248
# RBI 0.305270831966
# SB 0.106236078032
# CS 0.0839288761755
# BB 0.294358134397
# SO 0.247786615774
# IBB 0.246996855911
# HBP 0.211106125162
# SH 0.041282961062
# SF 0.24638105881
# GIDP 0.264540049204
# G_old 0.118267558949
# salary 0.800904840513
# pW 0.120192706874
# pL 0.0896800633549
# pG 0.0139799484312
# pGS 0.129312427313
# pCG 0.0681759434528
# pSHO 0.0685101583609
# pSV 0.0891755445389
# pIPouts 0.102476066383
# pH 0.0981864146695
# pER 0.0860171411974
# pHR 0.0995982638593
# pBB 0.0487784149404
# pSO 0.128320986681
# pERA -0.0705300512661
# pWP 0.0280316060022
# pHBP 0.0963736013036
# pBK -0.0603971195174
# pBFP 0.0984220050095
# pGF 0.0196078420888
# pR 0.0828057521287
# age 0.493370888471
# Batting_ratio -0.000720702723983
# ywc 0.458951668402
# G_cum -0.00538404932627
# G_batting_cum -0.0122625653937
# AB_cum -0.0117818712149
# R_cum -0.0118568502474
# H_cum -0.0117623913051
# X2B_cum -0.0112408576488
# X3B_cum -0.0085744884819
# HR_cum -0.0125662690841
# RBI_cum -0.0122729636285
# SB_cum -0.0126654741424
# CS_cum -0.0111655101357
# BB_cum -0.0109857372633
# SO_cum -0.0105965843365
# IBB_cum -0.0094185268835
# HBP_cum -0.0100927070463
# SH_cum -0.0118541374511
# SF_cum -0.0139289539641
# GIDP_cum -0.0116969356623
# salary_cum 0.00710571021008
# pW_cum 0.00737153188653
# pL_cum 0.00716368564594
# pG_cum 0.00498339021247
# pGS_cum 0.00754581378419
# pCG_cum 0.00824582442817
# pSHO_cum 0.00576245329396
# pSV_cum 0.000758326932369
# pIPouts_cum 0.00750057958468
# pH_cum 0.00727617510096
# pER_cum 0.00689456108889
# pHR_cum 0.00707774836594
# pBB_cum 0.00693068975357
# pSO_cum 0.00741057338896
# pERA_cum 0.00342295491897
# pWP_cum 0.00577471992393
# pHBP_cum 0.0066645531407
# pBK_cum 0.00655907416443
# pBFP_cum 0.00738729738058
# pGF_cum -0.000440764982435
# pR_cum 0.00685116015607
# log_ywc 0.442212141234
# log_salary 1.0
# log_G 0.22178671788
# log_G_batting 0.104161707255
# log_AB 0.173499396572
# log_R 0.199670997186
# log_H 0.191269944562
# log_X2B 0.224929060011
# log_X3B 0.0958297550661
# log_HR 0.27244059858
# log_RBI 0.215431603383
# log_SB 0.13166293629
# log_CS 0.0992032849435
# log_BB 0.210762702785
# log_SO 0.187961099134
# log_IBB 0.261188339686
# log_HBP 0.223508989134
# log_SH 0.0370370027772
# log_SF 0.248623281563
# log_GIDP 0.237366351766
# log_pW 0.092920602657
# log_pL 0.0802694790118
# log_pG -0.00801555011376
# log_pGS 0.0947500272732
# log_pCG 0.0725158101507
# log_pSHO 0.0507797290921
# log_pSV 0.0612561011006
# log_pIPouts 0.00267747528224
# log_pH 0.00935544581732
# log_pER 0.0126525745909
# log_pHR 0.0581121346634
# log_pBB 0.00226891990149
# log_pSO 0.0299784939892
# log_pERA -0.0647868967169
# log_pWP 0.0233407133944
# log_pHBP 0.0887335050255
# log_pBK -0.056388335004
# log_pBFP -0.00229613795743
# log_pGF -0.0654033222119
# log_pR 0.0101025487762

# %%
# Mean absolute error is our metric
def mape(y_pred,y_true): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
from sklearn import linear_model
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures, scale
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.decomposition import PCA
from itertools import combinations
from scipy.misc import comb 
# from sklearn import svm

# All the features at our disposal
# features = ['playerID', 'lahmanID', 'hofID', 'birthYear', 'birthMonth', 'birthDay',
# 'nameNick', 'weight', 'height', 'bats', 'throws', 'yearID', 'teamID', 'lgID', 'stint',
# 'G', 'G_batting', 'AB', 'R', 'H', 'X2B', 'X3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO',
# 'IBB', 'HBP', 'SH', 'SF', 'GIDP', 'G_old', 'salary', 'pW', 'pL', 'pG', 'pGS', 'pCG', 
# 'pSHO', 'pSV', 'pIPouts', 'pH', 'pER', 'pHR', 'pBB', 'pSO', 'pERA', 'pWP', 'pHBP', 
# 'pBK', 'pBFP', 'pGF', 'pR', 'age', 'Batting_ratio', 'ywc', 'G_cum', 'G_batting_cum', 
# 'AB_cum', 'R_cum', 'H_cum', 'X2B_cum', 'X3B_cum', 'HR_cum', 'RBI_cum', 'SB_cum', 
# 'CS_cum', 'BB_cum', 'SO_cum', 'IBB_cum', 'HBP_cum', 'SH_cum', 'SF_cum', 'GIDP_cum',
# 'salary_cum', 'pW_cum', 'pL_cum', 'pG_cum', 'pGS_cum', 'pCG_cum', 'pSHO_cum', 'pSV_cum',
# 'pIPouts_cum', 'pH_cum', 'pER_cum', 'pHR_cum', 'pBB_cum', 'pSO_cum', 'pERA_cum', 'pWP_cum',
# 'pHBP_cum', 'pBK_cum', 'pBFP_cum', 'pGF_cum', 'pR_cum', 'log_ywc', 'log_salary', 'log_G',
# 'log_G_batting', 'log_AB', 'log_R', 'log_H', 'log_X2B', 'log_X3B', 'log_HR', 'log_RBI',
# 'log_SB', 'log_CS', 'log_BB', 'log_SO', 'log_IBB', 'log_HBP', 'log_SH', 'log_SF', 
# 'log_GIDP', 'log_pW', 'log_pL', 'log_pG', 'log_pGS', 'log_pCG', 'log_pSHO', 'log_pSV',
# 'log_pIPouts', 'log_pH', 'log_pER', 'log_pHR', 'log_pBB', 'log_pSO', 'log_pERA',
# 'log_pWP', 'log_pHBP', 'log_pBK', 'log_pBFP', 'log_pGF', 'log_pR']

# We can search subsets to find which combos give good results
# features = ['hofID', 'birthYear', 'birthMonth',
# 'nameNick', 'weight', 'height', 'bats', 'throws', 'teamID',
# 'G', 'G_batting', 'AB', 'H', 'X2B', 'X3B', 'HR', 'SB', 'CS', 'BB', 'SO',
# 'IBB', 'HBP', 'SH', 'SF', 'GIDP', 'pW', 'pL', 'pG', 'pGS', 'pCG', 
# 'pSHO', 'pSV', 'pIPouts', 'pH', 'pER', 'pHR', 'pBB', 'pSO', 'pERA', 'pWP', 'pHBP', 
# 'pBK', 'pBFP', 'pGF', 'pR', 'Batting_ratio', 'G_cum', 'G_batting_cum', 
# 'AB_cum', 'H_cum', 'X2B_cum', 'X3B_cum', 'HR_cum', 'SB_cum', 
# 'CS_cum', 'BB_cum', 'SO_cum', 'IBB_cum', 'HBP_cum', 'SH_cum', 'SF_cum', 'GIDP_cum',
# 'salary_cum', 'pW_cum', 'pL_cum', 'pG_cum', 'pGS_cum', 'pCG_cum', 'pSHO_cum', 'pSV_cum',
# 'pIPouts_cum', 'pH_cum', 'pER_cum', 'pHR_cum', 'pBB_cum', 'pSO_cum', 'pERA_cum', 'pWP_cum',
# 'pHBP_cum', 'pBK_cum', 'pBFP_cum', 'pGF_cum', 'pR_cum', 'log_G',
# 'log_G_batting', 'log_AB', 'log_H', 'log_X2B', 'log_X3B', 'log_HR',
# 'log_SB', 'log_CS', 'log_BB', 'log_SO', 'log_IBB', 'log_HBP', 'log_SH', 'log_SF', 
# 'log_GIDP', 'log_pW', 'log_pL', 'log_pG', 'log_pGS', 'log_pCG', 'log_pSHO', 'log_pSV',
# 'log_pIPouts', 'log_pH', 'log_pER', 'log_pHR', 'log_pBB', 'log_pSO', 'log_pERA',
# 'log_pWP', 'log_pHBP', 'log_pBK', 'log_pBFP', 'log_pGF', 'log_pR','yearID','age',
# 'log_ywc','log_RBI','log_R','log_BB','log_pSO','log_HR']

# Some strong features here
features = ['yearID','age', 'log_ywc','log_RBI','log_R','log_BB','log_pSO','log_HR','hofID','nameNick']

# Set up polynomial of degree
clf = linear_model.LinearRegression()
degree = 3
polynomial_features = PolynomialFeatures(degree=degree,include_bias=True)
pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("classifier", clf)])
#     pipeline = svm.SVR(kernel='poly', degree=2)

# You can use this code to search a subset of 'features' for the best 'n_features'
best_mape = 1000
best_mape_features = []
n_features = 4
total_comb = comb(len(features),n_features)
print 'Combinations : ', total_comb

count = 0
for trial_features in combinations(features,n_features):
    X = df.ix[:,trial_features].values
    y = df[['log_salary']].values
# Do we need scaling?    
#     X = scale(X)
#     y = scale(y)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=33)
    
    # Train classifier
    pipeline.fit(X_train, y_train)
    
    # Predict on test data
    predict_y = pipeline.predict(X_test)

    # Some metrics
    cur_rsq = pipeline.score(X_test,y_test)
    cur_mse = mean_squared_error(predict_y, y_test)
    cur_mae = mean_absolute_error(predict_y, y_test)
    cur_mape = mape(predict_y,y_test)
    
    # Use mean absolute error as our main metric
    if cur_mape < best_mape:
        best_R = cur_rsq
        best_mse = cur_mse
        best_mae = cur_mae
        best_mape = cur_mape
        best_mape_features = trial_features
    count +=1
    
    # Update progress
    if count%(np.round(total_comb/10))==0:
        print count, ' of ', total_comb

print 'Best Summary:  '
print 'Features: ', best_mape_features
print 'MAPE: ', best_mape 
print 'R^2: ', (best_R)
print 'MSE: ', (best_mse)
print 'MAE: ', (best_mae)
# Out:
# Combinations :  210.0
# 21
#   of  210.0
# 42
#   of  210.0
# 63
#   of  210.0
# 84
#   of  210.0
# 105
#   of  210.0
# 126
#   of  210.0
# 147
#   of  210.0
# 168
#   of  210.0
# 189
#   of  210.0
# 210
#   of  210.0
# Best Summary:
# Features:  ('yearID', 'age', 'log_ywc', 'log_R')
# MAPE:  4.65302304255
# R^2:  0.650073802764
# MSE:  0.652754920253
# MAE:  0.631973100564

# %%
# Plot some scatter plots for our best feature combo
X = df.ix[:,best_R_features].values
y = df[['log_salary']].values
pipeline.fit(X, y)
predict_y = pipeline.predict(X)
f, axarr = plt.subplots(3, 3,figsize=(15,15))

# Plot model against data
# Note: labels are not accurate if the features change
axarr[0, 0].scatter(X[:,0],y)
axarr[0, 0].scatter(X[:,0],predict_y,color='r',alpha = 0.25)
axarr[0, 0].set_ylabel('log(salary)')
axarr[0, 0].set_xlabel('yearID')

axarr[0, 1].scatter(X[:,1],y)
axarr[0, 1].scatter(X[:,1],predict_y,color='r',alpha = 0.25)
axarr[0, 1].set_ylabel('log(salary)')
axarr[0, 1].set_xlabel('age')

axarr[0, 2].scatter(X[:,2],y)
axarr[0, 2].scatter(X[:,2],predict_y,color='r',alpha = 0.25)
axarr[0, 2].set_ylabel('log(salary)')
axarr[0, 2].set_xlabel('G_batting')

axarr[1, 0].scatter(X[:,3],y)
axarr[1, 0].scatter(X[:,3],predict_y,color='r',alpha = 0.25)
axarr[1, 0].set_ylabel('log(salary)')
axarr[1, 0].set_xlabel('G_pitching')

# axarr[1, 1].scatter(X[:,4],y)
# axarr[1, 1].scatter(X[:,4],predict_y,color='r',alpha = 0.25)
# axarr[1, 1].set_ylabel('log(salary)')
# axarr[1, 1].set_xlabel('Years with Club')

# axarr[1, 2].scatter(X[:,5],y)
# axarr[1, 2].scatter(X[:,5],predict_y,color='r',alpha = 0.25)
# axarr[1, 2].set_ylabel('log(salary)')
# axarr[1, 2].set_xlabel('R')

# axarr[2, 0].scatter(X[:,6],y)
# axarr[2, 0].scatter(X[:,6],predict_y,color='r',alpha = 0.25)
# axarr[2, 0].set_ylabel('log(salary)')
# axarr[2, 0].set_xlabel('H_cum')

# axarr[2, 1].scatter(X[:,7],y)
# axarr[2, 1].scatter(X[:,7],predict_y,color='r',alpha = 0.25)
# axarr[2, 1].set_ylabel('log(salary)')
# axarr[2, 1].set_xlabel('HR_cum')

plt.show()

# %%
# Is there any other plots or statistics we should look at from today's class?
