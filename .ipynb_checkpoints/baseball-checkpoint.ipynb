# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.simplefilter("ignore", DeprecationWarning)

# %%
fresh = 0
if fresh == 1:
    df = pd.read_csv('baseball.csv')
else:
    df = pd.read_pickle('df_baseball.pkl')

# %%
#1 "playerID" - Unique number 
#2 "lahmanID" - Unique code
#3 "managerID" - Manager ID
#4 "hofID" - Hall of fame ID
#5 "birthYear"
#6 "birthMonth"
#7 "birthDay"
#8 "birthCountry"
#9 "birthState"
#10 "birthCity"
#11 "deathYear"
#12 "deathMonth"
#13 "deathDay"
#14 "deathCountry"
#15 "deathState"
#16 "deathCity"
#17 "nameFirst"
#18 "nameLast"
#19 "nameNote" - Indicates changed name or played under diff name
#20 "nameGiven"
#21 "nameNick" - Nick name
#22 "weight" - weight in poinds
#23 "height" - height in inches
#24 "bats" - left, right, or both
#25 "throws" - left or right
#26 "debut" - date of first major league appearance
#27 "finalGame" - date of last ....
#28 "college" - College attended
#29 "lahman40ID" - lahman id 4.0
#30 "lahman45ID" - lahman id 4.5
#31 "retroID" - retrosheet id
#32 "holtzID" - Hotlz almanac ID
#33 "bbrefID" - Baseball reference website ID
#34 "deathDate"
#35 "birthDate"
#36 "yearID" - year for data
#37 "teamID" - team
#38 "lgID" - league
#39 "stint" - order of appearances within a season
#40 "G" - games
#41 "G_batting" - game as batter
#42 "AB" - at bats
#43 "R" - runs
#44 "H" - hits
#45 "X2B" - doubles 
#46 "X3B" - triples
#47 "HR" - homerunes
#48 "RBI" - runs batted in
#49 "SB" - stolen bases
#50 "CS" - caught stealing
#51 "BB" - base on balls
#52 "SO" - strikeouts
#53 "IBB" - intentional walks
#54 "HBP" - hit by pitch
#55 "SH" - sacrifice hits
#56 "SF" - sacrifice flies
#57 "GIDP" - grounded into double plays
#58 "G_old" - old verison of games
#59 "salary" - salary that year

# %%
#1 playerID       Player ID code
#2 yearID         Year
#3 stint          player's stint (order of appearances within a season)
#4 teamID         Team
#5 lgID           League
#6 W              Wins
#7 L              Losses
#8 G              Games
#9 GS             Games Started
#10 CG             Complete Games 
#11 SHO            Shutouts
#12 SV             Saves
#13 IPOuts         Outs Pitched (innings pitched x 3)
#14 H              Hits
#15 ER             Earned Runs
#16 HR             Homeruns
#17 BB             Walks
#18 SO             Strikeouts
#19 BAOpp          Opponent's Batting Average
#20 ERA            Earned Run Average
#21 IBB            Intentional Walks
#22 WP             Wild Pitches
#23 HBP            Batters Hit By Pitch
#24 BK             Balks
#25 BFP            Batters faced by Pitcher
#26 GF             Games Finished
#27 R              Runs Allowed
#28 SH             Sacrifices by opposing batters
#29 SF             Sacrifice flies by opposing batters
#30 GIDP           Grounded into double plays by opposing batter

# %%
def add_pitching(df_in):
    df_pitching = pd.read_csv('Pitching.csv')
    count = 0
    # Add new blank columns for all added pitching data
    zero_list = np.zeros([df_in.shape[0]]) 
    pitching_features = ['W', 'L', 'G', 'GS', 'CG', 'SHO', 'SV', 'IPouts', 'H', 'ER', 'HR', 'BB', 'SO', 'BAOpp', 'ERA', 'IBB', 'WP', 'HBP', 'BK', 'BFP', 'GF', 'R', 'SH', 'SF', 'GIDP']
    for feature in pitching_features:
        new_str = 'p'+feature
        df_in[new_str] = zero_list
        
    for row in df_in.iterrows():     
        cur_playerID = row[1].playerID
        cur_year = row[1].yearID
        row_lookup = (df_pitching.playerID == cur_playerID) & (df_pitching.yearID == cur_year)
        for feature in pitching_features:
            cur_val = df_pitching.loc[row_lookup,feature].values
            if len(cur_val)>0:
                cur_val = cur_val[0]
            else:
                cur_val = 0.0
            new_str = 'p'+feature
            df_in.ix[count,new_str] = cur_val
        count +=1
    return df_in

# %%
if fresh ==1:
    df = add_pitching(df)
    # Replace HOFID with binary 0 no, 1 yes
    df['hofID'].fillna(0.0,inplace=True)
    df.loc[df['hofID'] != 0.0,'hofID'] = 1.0
    # Replace nickname with binary
    df['nameNick'].fillna(0.0,inplace=True)
    df.loc[df['nameNick'] != 0.0,'nameNick'] = 1.0
    # Replace throws and bats L = 0, R = 1
    df.loc[df['bats'] =='L','bats'] = 0.0
    df.loc[df['bats'] =='R','bats'] = 1.0
    df.loc[df['bats'] =='B','bats'] = 2.0
    df.loc[df['throws'] =='L','throws'] = 0.0
    df.loc[df['throws'] =='R','throws'] = 1.0
    # Delete weird data
    df = df[df.salary > 1]
    df = df[df.yearID > 1]
    df = df[df.weight > 2]
    df = df[df.height > 2]
    df = df.drop(['debut','finalGame','managerID','deathYear','deathMonth','deathCountry','deathState','deathDate','deathDay', 'lahman40ID', 'lahman45ID', 'retroID', 'holtzID','deathCity','nameFirst','nameLast','nameNote'],axis=1)

    # Set NaN stats to zero
    for feature in df.columns:
        df[feature].fillna(0.0,inplace=True)
    
    # Add in age
    df['age'] = df['yearID']-df['birthYear']
    # Add in batting ratio -> 0 pitchers, 1 batters
    df['Batting_ratio']=df.G_batting/df.G
    # Sort for cumulative stats below
    df = df.sort(columns=['playerID','yearID'])
    df.index = range(0,len(df))

# %%
def add_ywc(df_in):
    count = 0
    df_in['ywc'] = np.zeros([df_in.shape[0]])
    for row in df_in.iterrows():
        if count == 0:
            df_in.ix[count,'ywc'] = 1
            prev_playerID = row[1].playerID
            prev_team = row[1].teamID
            prev_year = row[1].yearID
        else:            
            cur_playerID = row[1].playerID
            cur_team = row[1].teamID
            cur_year = row[1].yearID
            if cur_playerID == prev_playerID and cur_team == prev_team and cur_year == prev_year+1:
                df_in.ix[count,'ywc'] = df_in.ix[count-1,'ywc'] + 1
                prev_year = cur_year
            else:
                df_in.ix[count,'ywc'] = 1
                prev_playerID = cur_playerID
                prev_team = cur_team
                prev_year = cur_year
        
        count += 1
    return df_in

# %%
if fresh == 1:
    df = add_ywc(df)

# %%
def add_cum_stats(df_in):
    
    zero_list = np.zeros([df_in.shape[0]]) 
    features = ['G', 'G_batting', 'AB', 'R', 'H', 'X2B', 'X3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP','pW', 'pL', 'pG', 'pGS', 'pCG', 'pSHO', 'pSV', 'pIPouts', 'pH', 'pER', 'pHR', 'pBB', 'pSO', 'pBAOpp', 'pERA', 'pIBB', 'pWP', 'pHBP', 'pBK', 'pBFP', 'pGF', 'pR', 'pSH', 'pSF', 'pGIDP']
    for feature in features:
        new_str = feature + '_cum'
        df_in[new_str] = zero_list

    count = 0
    cur_playerID = ''   
    for row in df_in.iterrows(): 
        if row[1].playerID == cur_playerID:
            
            for feature in features:
                new_str = feature + '_cum'
                df_in.ix[count,new_str] = df_in.ix[count-1,new_str] + df_in.ix[count,feature] 
        else:
            for feature in features:
                new_str = feature + '_cum'
                df_in.ix[count,new_str] = df_in.ix[count,feature] 
            cur_playerID = row[1].playerID
        count += 1
        if count > 30:
            break
    df_in['Batting_ratio_cum']=df_in.G_batting_cum/df_in.G_cum    
    return df_in

# %%
if fresh == 1:
    df = add_cum_stats(df)

# %%
def replace_teams(df_in):
    pay_dict = {'TBA':0.563012316,
    'FLO':0.590202151,
    'WAS':0.628968556,
    'MON':0.640852974,
    'PIT':0.644590508,
    'MIL':0.765931924,
    'SDN':0.810817752,
    'ML4':0.821061606,
    'OAK':0.830736393,
    'MIN':0.851800958,
    'KCA':0.855405149,
    'CLE':0.864584478,
    'CIN':0.895130092,
    'COL':0.900445365,
    'ARI':0.949687104,
    'HOU':0.985782018,
    'ANA':0.992457703,
    'SEA':0.993221428,
    'TEX':0.996291621,
    'CAL':1.020107846,
    'CHA':1.029691571,
    'BAL':1.030425975,
    'PHI':1.031248116,
    'DET':1.037312589,
    'TOR':1.037545033,
    'SLN':1.066267649,
    'SFN':1.076192579,
    'CHN':1.173932516,
    'ATL':1.213932799,
    'LAN':1.250521203,
    'MIA':1.258127264,
    'NYN':1.307755738,
    'LAA':1.317793839,
    'BOS':1.388804819,
    'NYA':1.814579156}   
    for team in pay_dict.keys():
        df_in.replace(to_replace=team,value=pay_dict[team],inplace=True)
    return df_in

# %%
if fresh == 1:
    df = replace_teams(df)

# %%
def log_stats(df_in):
    # Take log of some data
    df_in['log_ywc'] = np.log(df_in.ywc)
    df_in['log_salary'] = np.log(df_in.salary)
    # Use logs for cumulative stats
    features = ['G', 'G_batting', 'AB', 'R', 'H', 'X2B', 'X3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP','pW', 'pL', 'pG', 'pGS', 'pCG', 'pSHO', 'pSV', 'pIPouts', 'pH', 'pER', 'pHR', 'pBB', 'pSO', 'pBAOpp', 'pERA', 'pIBB', 'pWP', 'pHBP', 'pBK', 'pBFP', 'pGF', 'pR', 'pSH', 'pSF', 'pGIDP']        
    for feature in features:
        cum_feature = feature + '_cum'
        new_str = 'log_' + cum_feature
        df_in[new_str] = df_in[cum_feature]
        select_gt_zero = df_in[cum_feature]>0
        df_in.loc[select_gt_zero,new_str] = np.log(df_in.loc[select_gt_zero,cum_feature])
    return df_in

# %%
if fresh == 1:
    df = log_stats(df)

# %%
# df[['yearID','playerID','H','H_cum','log_H_cum','pSO','pSO_cum','log_pSO_cum','teamID']]
df.to_pickle('df_baseball.pkl')

# %%
df[['playerID','AB','AB_cum']]
# Out:
#      playerID   AB  AB_cum
# 0   aardsda01    0       0
# 1   aardsda01    0       0
# 2   aardsda01    1       1
# 3   aardsda01    0       1
# 4   aardsda01    0       1
# 5   aardsda01    0       1
# 6    aasedo01    0       0
# 7    aasedo01    0       0
# 8    aasedo01    0       0
# 9    aasedo01    5       5
# 10   abadan01    3       3
# 11   abadfe01    0       0
# 12   abadfe01    7       7
# 13  abbotje01  244     244
# 14  abbotje01   57     301
# 15  abbotje01  215     516
# 16  abbotje01   42     558
# 17  abbotji01    0       0
# 18  abbotji01    0       0
# 19  abbotji01    0       0
# 20  abbotji01    0       0
# 21  abbotji01    0       0
# 22  abbotji01    0       0
# 23  abbotji01    0       0
# 24  abbotji01    0       0
# 25  abbotji01   21      21
# 26  abbotku01   61      61
# 27  abbotku01  345     406
# 28  abbotku01  420     826
# 29  abbotku01  320    1146
# 30  abbotku01  252    1398
# 31  abbotku01  123       0
# 32  abbotku01  286       0
# 33  abbotku01  157       0
# 34  abbotku01    9       0
# 35  abbotky01   29       0
# 36  abbotky01    2       0
# 37  abbotpa01    0       0
# 38  abbotpa01    0       0
# 39  abbotpa01    0       0
# 40  abbotpa01    5       0
# 41  abbotpa01    4       0
# 42  abbotpa01    0       0
# 43  abbotpa01    0       0
# 44  abercre01  255       0
# 45  abernbr01  463       0
# 46  abernbr01    7       0
# 47  abnersh01   83       0
# 48  abnersh01  102       0
# 49  abnersh01  184       0
# 50  abnersh01  115       0
# 51  abnersh01  208       0
# 52  abreubo01  188       0
# 53  abreubo01  497       0
# 54  abreubo01  546       0
# 55  abreubo01  576       0
# 56  abreubo01  588       0
# 57  abreubo01  572       0
# 58  abreubo01  577       0
# 59  abreubo01  574       0
#           ...  ...     ...
#
# [22084 rows x 3 columns]

# %%
from sklearn import linear_model
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.decomposition import PCA
from itertools import combinations
from scipy.misc import comb
# from sklearn import svm
# features = ['birthMonth', 'nameNick', 'weight', 'height', 'bats',
#             'throws', 'yearID', 'teamID', 'G', 'G_batting',
#             'AB', 'R', 'H', 'X2B', 'X3B', 'HR', 'RBI', 'SB', 'CS', 
#             'BB', 'SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP', 'pW', 'pL',
#             'pG', 'pGS', 'pCG', 'pSHO', 'pSV', 'pIPouts', 'pH', 'pER', 
#             'pHR', 'pBB', 'pSO', 'pBAOpp', 'pERA', 'pIBB', 'pWP', 'pHBP',
#             'pBK', 'pBFP', 'pGF', 'pR', 'pSH', 'pSF', 'pGIDP', 'age',
#             'Batting_ratio', 'ywc', 'G_cum', 'G_batting_cum', 'AB_cum',
#             'R_cum', 'H_cum', 'X2B_cum', 'X3B_cum', 'HR_cum', 'RBI_cum', 
#             'SB_cum', 'CS_cum', 'BB_cum', 'SO_cum', 'IBB_cum', 'HBP_cum', 
#             'SH_cum', 'SF_cum', 'GIDP_cum', 'pW_cum', 'pL_cum', 'pG_cum', 
#             'pGS_cum', 'pCG_cum', 'pSHO_cum', 'pSV_cum', 'pIPouts_cum',
#             'pH_cum', 'pER_cum', 'pHR_cum', 'pBB_cum', 'pSO_cum', 'pBAOpp_cum', 
#             'pERA_cum', 'pIBB_cum', 'pWP_cum', 'pHBP_cum', 'pBK_cum', 'pBFP_cum',
#             'pGF_cum', 'pR_cum', 'pSH_cum', 'pSF_cum', 'pGIDP_cum',
#             'log_ywc', 'log_G_cum', 'log_G_batting_cum', 'log_AB_cum',
#             'log_R_cum', 'log_H_cum', 'log_X2B_cum', 'log_X3B_cum', 'log_HR_cum',
#             'log_RBI_cum', 'log_SB_cum', 'log_CS_cum', 'log_BB_cum', 'log_SO_cum', 
#             'log_IBB_cum', 'log_HBP_cum', 'log_SH_cum', 'log_SF_cum', 'log_GIDP_cum',
#             'log_pW_cum', 'log_pL_cum', 'log_pG_cum', 'log_pGS_cum', 'log_pCG_cum', 
#             'log_pSHO_cum', 'log_pSV_cum', 'log_pIPouts_cum', 'log_pH_cum', 'log_pER_cum',
#             'log_pHR_cum', 'log_pBB_cum', 'log_pSO_cum', 'log_pBAOpp_cum', 'log_pERA_cum', 
#             'log_pIBB_cum', 'log_pWP_cum', 'log_pHBP_cum', 'log_pBK_cum', 'log_pBFP_cum', 
#             'log_pGF_cum', 'log_pR_cum', 'log_pSH_cum', 'log_pSF_cum', 'log_pGIDP_cum']


features = ['birthMonth', 'nameNick', 'weight', 'height', 'bats',
            'throws', 'teamID', 'G', 'G_batting',
            'AB', 'H', 'X2B', 'X3B', 'HR', 'SB', 'CS', 
            'SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP', 'pW', 'pL',
            'pG', 'pGS', 'pCG', 'pSHO', 'pSV', 'pH', 'pER', 
            'pHR', 'pBB', 'pERA', 'pIBB', 'pWP', 'pHBP',
            'pBK', 'pBFP', 'pGF', 'pR', 'pSH', 'pSF', 'pGIDP', 
            'Batting_ratio', 'G_cum', 'G_batting_cum', 'AB_cum',
            'R_cum', 'H_cum', 'X2B_cum', 'X3B_cum', 'HR_cum', 'RBI_cum', 
            'SB_cum', 'CS_cum', 'BB_cum', 'SO_cum', 'IBB_cum', 'HBP_cum', 
            'SH_cum', 'SF_cum', 'GIDP_cum', 'pW_cum', 'pL_cum', 'pG_cum', 
            'pGS_cum', 'pCG_cum', 'pSHO_cum', 'pSV_cum', 'pIPouts_cum',
            'pH_cum', 'pER_cum', 'pHR_cum', 'pBB_cum', 'pSO_cum', 'pBAOpp_cum', 
            'pERA_cum', 'pIBB_cum', 'pWP_cum', 'pHBP_cum', 'pBK_cum', 'pBFP_cum',
            'pGF_cum', 'pR_cum', 'pSH_cum', 'pSF_cum', 'pGIDP_cum','log_G_cum', 'log_G_batting_cum', 'log_AB_cum',
            'log_R_cum', 'log_H_cum', 'log_X2B_cum', 'log_X3B_cum', 'log_HR_cum',
            'log_RBI_cum', 'log_SB_cum', 'log_CS_cum', 'log_BB_cum', 'log_SO_cum', 
            'log_IBB_cum', 'log_HBP_cum', 'log_SH_cum', 'log_SF_cum', 'log_GIDP_cum',
            'log_pW_cum', 'log_pL_cum', 'log_pG_cum', 'log_pGS_cum', 'log_pCG_cum', 
            'log_pSHO_cum', 'log_pSV_cum', 'log_pIPouts_cum', 'log_pH_cum', 'log_pER_cum',
            'log_pHR_cum', 'log_pBB_cum', 'log_pSO_cum', 'log_pBAOpp_cum', 'log_pERA_cum', 
            'log_pIBB_cum', 'log_pWP_cum', 'log_pHBP_cum', 'log_pBK_cum', 'log_pBFP_cum', 
            'log_pGF_cum', 'log_pR_cum', 'log_pSH_cum', 'log_pSF_cum', 'log_pGIDP_cum']
best_R = 0
best_R_features = []
n_features = 2
total_comb = comb(len(features),n_features)
print 'Combinations : ', total_comb
count = 0
for trial_features in combinations(features,n_features):#[['yearID','age', 'log_ywc','RBI','BB', 'pSO','R','pIPouts','H','pG']]:#combinations(features,n_features):

    X = df.ix[:,trial_features].values
    y = df[['log_salary']].values

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=33)

    clf = linear_model.LinearRegression()
    degree = 3

    polynomial_features = PolynomialFeatures(degree=degree,
                                                 include_bias=False)
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                             ("classifier", clf)])
    # #     pipeline = svm.SVR(kernel='poly', degree=2)
    pipeline.fit(X_train, y_train)

    predict_y = pipeline.predict(X_test)

    cur_rsq = pipeline.score(X_test,y_test)
    cur_mse = mean_squared_error(predict_y, y_test)
    cur_mae = mean_absolute_error(predict_y, y_test)
    if cur_rsq > best_R:
        best_R = cur_rsq
        best_mse = cur_mse
        best_mae = cur_mae
        best_R_features = trial_features
    count +=1
    if count%(np.round(total_comb/10))==0:
        print count, ' of ', total_comb

print 'Best Summary:  '
print 'Features: ', best_R_features
print 'R^2: ', (best_R)
print 'MSE: ', (best_mse)
print 'MAE: ', (best_mae)
# Out:
# Combinations :  131.0
# Best Summary:
# Features:  ('age',)
# R^2:  0.268412075453
# MSE:  1.36470953337
# MAE:  0.948562238489

# %%
predict_y = pipeline.predict(X)
f, axarr = plt.subplots(3, 3,figsize=(15,15))

# Plot model against data
axarr[0, 0].scatter(X[:,0],y)
axarr[0, 0].scatter(X[:,0],predict_y,color='r',alpha = 0.25)
axarr[0, 0].set_ylabel('log(salary)')
axarr[0, 0].set_xlabel('yearID')

# axarr[0, 1].scatter(X[:,1],y)
# axarr[0, 1].scatter(X[:,1],predict_y,color='r',alpha = 0.25)
# axarr[0, 1].set_ylabel('log(salary)')
# axarr[0, 1].set_xlabel('age')

# axarr[0, 2].scatter(X[:,2],y)
# axarr[0, 2].scatter(X[:,2],predict_y,color='r',alpha = 0.25)
# axarr[0, 2].set_ylabel('log(salary)')
# axarr[0, 2].set_xlabel('G_batting')

# axarr[1, 0].scatter(X[:,3],y)
# axarr[1, 0].scatter(X[:,3],predict_y,color='r',alpha = 0.25)
# axarr[1, 0].set_ylabel('log(salary)')
# axarr[1, 0].set_xlabel('G_pitching')

# axarr[1, 1].scatter(X[:,4],y)
# axarr[1, 1].scatter(X[:,4],predict_y,color='r',alpha = 0.25)
# axarr[1, 1].set_ylabel('log(salary)')
# axarr[1, 1].set_xlabel('Years with Club')

# axarr[1, 2].scatter(X[:,5],y)
# axarr[1, 2].scatter(X[:,5],predict_y,color='r',alpha = 0.25)
# axarr[1, 2].set_ylabel('log(salary)')
# axarr[1, 2].set_xlabel('R_cum')

# axarr[2, 0].scatter(X[:,6],y)
# axarr[2, 0].scatter(X[:,6],predict_y,color='r',alpha = 0.25)
# axarr[2, 0].set_ylabel('log(salary)')
# axarr[2, 0].set_xlabel('H_cum')

# axarr[2, 1].scatter(X[:,7],y)
# axarr[2, 1].scatter(X[:,7],predict_y,color='r',alpha = 0.25)
# axarr[2, 1].set_ylabel('log(salary)')
# axarr[2, 1].set_xlabel('HR_cum')

plt.show()
